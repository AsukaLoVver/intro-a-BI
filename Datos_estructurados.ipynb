# %% [markdown]
# <a href="https://colab.research.google.com/github/AsukaLoVver/intro-a-BI/blob/main/Datos_estructurados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datos estructurados
#
# En lo que respecta a los datos estructurados, iniciaremos con la lectura de archivos en formato excel.

# %%
# importamos librerias necesarias

import pandas as pd

# cargamos la BD de emily

emily_hoteles = pd.read_excel('/content/Tabla clase 2.xlsx', sheet_name = 'Hoteles')

emily_vuelos = pd.read_excel('/content/Tabla clase 2.xlsx', sheet_name= 'Vuelos')

# %%
print (emily_hoteles)
print (emily_vuelos)
# Out:
#       Nombre del hotel      Precio  Reviews  Score
# 0      The Red Hut inn   726000.00      147    7.8
# 1              Jovilee  1019000.00       11    9.8
# 2          See belize   1031000.00        2    2.0
# 3  Best time inn hotel     1049.53      168    6.8
# 4              Sky Inn     1049.53       28    9.0
# 5  Caye Caulker beach      1102.45       17    9.2
# 6            DB Towers     1137.82       46    8.4
# 7             Easy Inn     1163.29      162    7.8
# 8       Ramada Belize      1186.45     1001    6.4
# 9    Golden Tree Hotel     1217.20        2    5.0
#            Aerolinea  Precio  Escalas     Tiempo
# 0   Alaska Airlines   397.30         0  04:41:00
# 1  American Airlines  408.05         1  04:38:00
# 2   United Airlines   408.05         1  03:37:00
# 3   United Airlines   408.05         1  04:27:00
# 4  American Airlines  408.05         1  06:38:00
# 5   United Airlines   408.05         1  09:03:00
# 6   United Airlines   408.05         1  10:28:00
# ...

# %%
emily_vuelos.head()      # head muestra primeros 5
# Out:
#            Aerolinea  Precio  Escalas     Tiempo
# 0   Alaska Airlines   397.30         0  04:41:00
# 1  American Airlines  408.05         1  04:38:00
# 2   United Airlines   408.05         1  03:37:00
# 3   United Airlines   408.05         1  04:27:00
# 4  American Airlines  408.05         1  06:38:00

# %%
emily_vuelos.tail()     #tail muestra ultimos 5
# Out:
#            Aerolinea  Precio  Escalas     Tiempo
# 3   United Airlines   408.05         1  04:27:00
# 4  American Airlines  408.05         1  06:38:00
# 5   United Airlines   408.05         1  09:03:00
# 6   United Airlines   408.05         1  10:28:00
# 7   United Airlines   408.05         1  11:15:00

# %%
emily_hoteles.describe()     # promedios y datos adicionales
# Out:
#              Precio     Reviews      Score
# count  1.000000e+01    10.00000  10.000000
# mean   2.783906e+05   158.40000   7.220000
# std    4.537980e+05   303.77082   2.329425
# min    1.049530e+03     2.00000   2.000000
# 25%    1.111293e+03    12.50000   6.500000
# 50%    1.174870e+03    37.00000   7.800000
# 75%    5.448043e+05   158.25000   8.850000
# max    1.031000e+06  1001.00000   9.800000

# %%
# mostraremos las aerolineas que tiene emily contempladas en su base de datos
aerolineas = emily_vuelos['Aerolinea']

aerolineas

unicas = aerolineas.unique()     # seleccionamos los valores que no se repiten y los guardamos como una variable unica

unicas
# Out:
# array(['Alaska Airlines ', 'American Airlines', 'United Airlines '],
#       dtype=object)

# %%
print('las aerolineas seleccionadas por emily son' , unicas)
# Out:
# las aerolineas seleccionadas por emily son ['Alaska Airlines ' 'American Airlines' 'United Airlines ']

# %% [markdown]
# ahora queremos saber cual aerolinea tiene el valor mas bajo

# %%
# prompt: min aerolinea

min_aerolinea = emily_vuelos['Aerolinea'].min()
print('La aerolinea con el valor mas bajo es:', min_aerolinea)
# Out:
# La aerolinea con el valor mas bajo es: Alaska Airlines
